# %%
import numpy as np
from importlib import reload
import matplotlib.pyplot as plt
import Source.Particle as Particle
import Source.Particles as Particles
import Source.Parabolas as Parabolas
import Functions.Electric_fields as Electric_fields
import Functions.Qfactors as Qfactors

plt.style.use("ggplot")
plt.rcParams["figure.dpi"] = 300

reload(Particle) # for debugging, can be removed
reload(Particles)
reload(Parabolas) # for debugging, can be removed
reload(Electric_fields) # for debugging, can be removed
reload(Qfactors); # for debugging, can be removed

# %%
path = "parameters.yaml"
foo = Particles.Particles(path)
foo.params
foo.create()
# Out:
# Constants of motion:
# 	Particle Energy (normalized):	E  = 9.785310e-06
# 	Particle Energy (eV):		E  = 9.785310e-06 eV
# 	Toroidal Momenta:		Pζ = -0.0272
#
# Other Quantities:
# 	Particle of Species:		"e"
# 	Orbit Type:			Trapped - Confined
# 	Major Radius:			R = 1 meters
# 	Time unit:			ω = 1.000000e+00 Hz
#
# Constants of motion:
# 	Particle Energy (normalized):	E  = 4.930422e-05
# 	Particle Energy (eV):		E  = 4.930422e-05 eV
# 	Toroidal Momenta:		Pζ = -0.0272
#
# Other Quantities:
# 	Particle of Species:		"e"
# 	Orbit Type:			Passing - Confined
# 	Major Radius:			R = 1 meters
# 	Time unit:			ω = 1.000000e+00 Hz
#
# Constants of motion:
# 	Particle Energy (normalized):	E  = 1.283619e-04
# 	Particle Energy (eV):		E  = 1.283619e-04 eV
# 	Toroidal Momenta:		Pζ = -0.0272
#
# Other Quantities:
# 	Particle of Species:		"e"
# 	Orbit Type:			Passing - Confined
# 	Major Radius:			R = 1 meters
# 	Time unit:			ω = 1.000000e+00 Hz
#
# Constants of motion:
# 	Particle Energy (normalized):	E  = 9.785310e-06
# 	Particle Energy (eV):		E  = 9.785310e-06 eV
# 	Toroidal Momenta:		Pζ = -0.0272
#
# Other Quantities:
# 	Particle of Species:		"e"
# 	Orbit Type:			Trapped - Confined
# 	Major Radius:			R = 1 meters
# 	Time unit:			ω = 1.000000e+00 Hz
#
# Constants of motion:
# 	Particle Energy (normalized):	E  = 4.930422e-05
# 	Particle Energy (eV):		E  = 4.930422e-05 eV
# 	Toroidal Momenta:		Pζ = -0.0272
#
# Other Quantities:
# 	Particle of Species:		"e"
# 	Orbit Type:			Passing - Confined
# 	Major Radius:			R = 1 meters
# 	Time unit:			ω = 1.000000e+00 Hz
#
# Constants of motion:
# 	Particle Energy (normalized):	E  = 1.283619e-04
# 	Particle Energy (eV):		E  = 1.283619e-04 eV
# 	Toroidal Momenta:		Pζ = -0.0272
#
# Other Quantities:
# 	Particle of Species:		"e"
# 	Orbit Type:			Passing - Confined
# 	Major Radius:			R = 1 meters
# 	Time unit:			ω = 1.000000e+00 Hz
#
# Constants of motion:
# 	Particle Energy (normalized):	E  = 9.785310e-06
# 	Particle Energy (eV):		E  = 9.785310e-06 eV
# 	Toroidal Momenta:		Pζ = -0.0272
#
# Other Quantities:
# 	Particle of Species:		"e"
# 	Orbit Type:			Trapped - Confined
# 	Major Radius:			R = 1 meters
# 	Time unit:			ω = 1.000000e+00 Hz
#
# Constants of motion:
# 	Particle Energy (normalized):	E  = 4.930422e-05
# 	Particle Energy (eV):		E  = 4.930422e-05 eV
# 	Toroidal Momenta:		Pζ = -0.0272
#
# Other Quantities:
# 	Particle of Species:		"e"
# 	Orbit Type:			Passing - Confined
# 	Major Radius:			R = 1 meters
# 	Time unit:			ω = 1.000000e+00 Hz
#
# Constants of motion:
# 	Particle Energy (normalized):	E  = 1.283619e-04
# 	Particle Energy (eV):		E  = 1.283619e-04 eV
# 	Toroidal Momenta:		Pζ = -0.0272
#
# Other Quantities:
# 	Particle of Species:		"e"
# 	Orbit Type:			Passing - Confined
# 	Major Radius:			R = 1 meters
# 	Time unit:			ω = 1.000000e+00 Hz

# %%
foo.plot_Ptheta_drifts(
    theta_lim = [-np.pi ,np.pi]
)
